# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#file = pd.read_csv("226(normal).csv")
file = pd.read_csv("1681815045818.csv")
file
# Out:
#                               message   results  ratio  elements  numberLeft  \
# 0               TwoHash: 100000 & 0.9    325151    0.9     25000      100000
# 1               TwoHash: 100000 & 0.9    896911    0.9      9000      100000
# 2   TwoHashIndexedCount: 100000 & 0.9    162923    0.9     50000      100000
# 3               TwoHash: 100000 & 0.9    162923    0.9     50000      100000
# 4   TwoHashIndexedCount: 100000 & 0.9   8030254    0.9      1000      100000
# 5               TwoHash: 100000 & 0.9   8030254    0.9      1000      100000
# 6   TwoHashIndexedCount: 100000 & 0.9    896911    0.9      9000      100000
# 7   TwoHashIndexedCount: 100000 & 0.9    325151    0.9     25000      100000
# 8               TwoHash: 100000 & 0.9    108891    0.9     75000      100000
# 9   TwoHashIndexedCount: 100000 & 0.9    108891    0.9     75000      100000
# 10  TwoHashIndexedCount: 100000 & 0.9   8030254    0.9      1000      100000
# 11              TwoHash: 100000 & 0.9   8030254    0.9      1000      100000
# 12              TwoHash: 100000 & 0.9    325151    0.9     25000      100000
# 13  TwoHashIndexedCount: 100000 & 0.9    325151    0.9     25000      100000
# 14              TwoHash: 100000 & 0.9    162923    0.9     50000      100000
# 15              TwoHash: 100000 & 0.9    108891    0.9     75000      100000
# 16  TwoHashIndexedCount: 100000 & 0.9    896911    0.9      9000      100000
# 17              TwoHash: 100000 & 0.9    896911    0.9      9000      100000
# 18  TwoHashIndexedCount: 100000 & 0.9    162923    0.9     50000      100000
# 19  TwoHashIndexedCount: 100000 & 0.9    108891    0.9     75000      100000
# 20              TwoHash: 200000 & 0.9    650296    0.9     50000      200000
# 21  TwoHashIndexedCount: 200000 & 0.9  16112950    0.9      2000      200000
# 22  TwoHashIndexedCount: 200000 & 0.9    650296    0.9     50000      200000
# 23  TwoHashIndexedCount: 200000 & 0.9    215972    0.9    150000      200000
# 24  TwoHashIndexedCount: 200000 & 0.9    323309    0.9    100000      200000
# 25              TwoHash: 200000 & 0.9    215972    0.9    150000      200000
# 26              TwoHash: 200000 & 0.9    323309    0.9    100000      200000
# 27              TwoHash: 200000 & 0.9  16112950    0.9      2000      200000
# 28              TwoHash: 200000 & 0.9   1802452    0.9     18000      200000
# 29  TwoHashIndexedCount: 200000 & 0.9   1802452    0.9     18000      200000
# 30              TwoHash: 500000 & 0.9  40380530    0.9      5000      500000
# 31  TwoHashIndexedCount: 500000 & 0.9    541462    0.9    375000      500000
# 32  TwoHashIndexedCount: 500000 & 0.9  40380530    0.9      5000      500000
# 33              TwoHash: 500000 & 0.9    541462    0.9    375000      500000
# 34              TwoHash: 500000 & 0.9   4507952    0.9     45000      500000
# 35  TwoHashIndexedCount: 500000 & 0.9   1623567    0.9    125000      500000
# 36  TwoHashIndexedCount: 500000 & 0.9   4507952    0.9     45000      500000
# 37              TwoHash: 500000 & 0.9   1623567    0.9    125000      500000
# 38  TwoHashIndexedCount: 500000 & 0.9    813142    0.9    250000      500000
# 39              TwoHash: 500000 & 0.9    813142    0.9    250000      500000
#
#     numberRight   joinIteratorString  execution time  heapTotal diff  \
# 0        100000              TwoHash       15.008782       25.359375
# 1        100000              TwoHash       16.096637       25.093750
# 2        100000  TwoHashIndexedCount       17.598706       28.046875
# 3        100000              TwoHash       19.919587       33.406250
# 4        100000  TwoHashIndexedCount       20.178953       18.867188
# 5        100000              TwoHash       20.759571       18.000000
# 6        100000  TwoHashIndexedCount       21.238880       20.257812
# 7        100000  TwoHashIndexedCount       21.170762       27.328125
# 8        100000              TwoHash       21.192887       38.914062
# 9        100000  TwoHashIndexedCount       21.465135       43.562500
# 10       100000  TwoHashIndexedCount       22.227874       17.867188
# 11       100000              TwoHash       23.739769       17.750000
# 12       100000              TwoHash       16.643022       25.906250
# 13       100000  TwoHashIndexedCount       19.016681       22.539062
# 14       100000              TwoHash       18.687038       35.906250
# 15       100000              TwoHash       20.670781       32.378906
# 16       100000  TwoHashIndexedCount       20.379272       19.757812
# 17       100000              TwoHash       20.975245       25.343750
# 18       100000  TwoHashIndexedCount       23.225069       36.546875
# 19       100000  TwoHashIndexedCount       23.152649       43.093750
# 20       200000              TwoHash      161.351331        5.914062
# 21       200000  TwoHashIndexedCount      172.852775        7.035156
# 22       200000  TwoHashIndexedCount      181.692827       29.511719
# 23       200000  TwoHashIndexedCount      165.206093       77.800781
# 24       200000  TwoHashIndexedCount      172.676894       49.562500
# 25       200000              TwoHash      174.563182       55.183594
# 26       200000              TwoHash      185.751561       42.175781
# 27       200000              TwoHash      199.656948        9.351562
# 28       200000              TwoHash      183.928125       -4.406250
# 29       200000  TwoHashIndexedCount      198.319497        5.375000
# 30       500000              TwoHash     1510.182039      -11.046875
# 31       500000  TwoHashIndexedCount     1392.287819      178.949219
# 32       500000  TwoHashIndexedCount     1568.183727       -9.632812
# 33       500000              TwoHash     1447.948091      165.003906
# 34       500000              TwoHash     1439.489388       -5.070312
# 35       500000  TwoHashIndexedCount     1478.581284       59.816406
# 36       500000  TwoHashIndexedCount     1458.222934       -2.765625
# 37       500000              TwoHash     1500.957398       53.906250
# 38       500000  TwoHashIndexedCount     1486.966058      149.792969
# 39       500000              TwoHash     1498.668421      128.769531
#
#     heapTotal total  arrayBuffers dif  arrayBuffers total     rss diff  \
# 0         92.675781                 0            0.017817   268.203125
# 1         80.863281                 0            0.017817   428.511719
# 2        100.324219                 0            0.017817   240.570312
# 3        102.203125                 0            0.017817   291.023438
# 4         76.144531                 0            0.017817   391.679688
# 5         73.519531                 0            0.017817   272.828125
# 6         83.355469                 0            0.017817   348.656250
# 7         95.511719                 0            0.017817   219.812500
# 28  2434.945312  -15.327103   41.196663           0.09
# 29  2338.996094    4.766197   60.936584           0.09
# 30  2560.062500   14.022644  158.552856           0.01
# 31  2485.433594  169.226570  386.738220           0.75
# 32  2086.089844    3.401810  151.822273           0.01
# 33  2088.121094  149.231850  357.413307           0.75
# 34  1708.296875  -30.264969  168.248901           0.09
# 35  1590.156250   37.664459  238.177155           0.25
# 36  1308.546875    4.254250  193.102615           0.09
# 37  1109.714844   23.536011  227.688057           0.25
# 38   855.148438  137.269409  347.392609           0.50
# 39   498.671875  120.432129  339.517746           0.50

# %%
fig, ax = plt.subplots()
fig.set_figheight(15)
fig.set_figwidth(28)
for key1, grp1 in file.groupby(['numberRight', 'joinIteratorString']):
    #for key2, grp2 in grp1.groupby([]):
    if key1["numberRight"] != 500000:
        ax = grp1.plot(ax=ax, kind='line', x='elementsRatio', y='execution time', label= str(key1))
plt.legend(loc='best')
plt.show()

# %%
fig, ax = plt.subplots()
fig.set_figheight(15)
fig.set_figwidth(28)
for key1, grp1 in file.groupby(['ratio']):
    for key2, grp2 in grp1.groupby(['joinIteratorString']):
        ax = grp2.plot(ax=ax, kind='line', x='numberRight', y='execution time', label= str(key1) + "; " + str(key2))
plt.legend(loc='best')
plt.show()
#file.plot(x="numberRight", y="execution time")
# Out:
# /tmp/ipykernel_19590/1952244149.py:4: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for key1, grp1 in file.groupby(['ratio']):
# /tmp/ipykernel_19590/1952244149.py:5: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for key2, grp2 in grp1.groupby(['joinIteratorString']):

# %%
fig, ax = plt.subplots()
fig.set_figheight(15)
fig.set_figwidth(28)
for key1, grp1 in file.groupby(['ratio']):
    for key2, grp2 in grp1.groupby(['joinIteratorString']):
        ax = grp2.plot(ax=ax, kind='line', x='numberRight', y='rss total', label= str(key1) + "; " + str(key2))
plt.legend(loc='best')
plt.show()
#file.plot(x="numberRight", y="execution time")
# Out:
# /tmp/ipykernel_19590/1300170136.py:4: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for key1, grp1 in file.groupby(['ratio']):
# /tmp/ipykernel_19590/1300170136.py:5: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for key2, grp2 in grp1.groupby(['joinIteratorString']):
# /tmp/ipykernel_19590/1300170136.py:5: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for key2, grp2 in grp1.groupby(['joinIteratorString']):
# /tmp/ipykernel_19590/1300170136.py:5: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for key2, grp2 in grp1.groupby(['joinIteratorString']):
# /tmp/ipykernel_19590/1300170136.py:5: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for key2, grp2 in grp1.groupby(['joinIteratorString']):

# %%
fig, ax = plt.subplots()
fig.set_figheight(15)
fig.set_figwidth(28)
for key1, grp1 in file.groupby(['ratio']):
    for key2, grp2 in grp1.groupby(['joinIteratorString']):
        ax = grp2.plot(ax=ax, kind='line', x='numberRight', y='heapTotal total', label= str(key1) + "; " + str(key2))
plt.legend(loc='best')
plt.show()
# Out:
# /tmp/ipykernel_19590/3127026116.py:4: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for key1, grp1 in file.groupby(['ratio']):
# /tmp/ipykernel_19590/3127026116.py:5: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for key2, grp2 in grp1.groupby(['joinIteratorString']):
# /tmp/ipykernel_19590/3127026116.py:5: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for key2, grp2 in grp1.groupby(['joinIteratorString']):
# /tmp/ipykernel_19590/3127026116.py:5: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for key2, grp2 in grp1.groupby(['joinIteratorString']):
# /tmp/ipykernel_19590/3127026116.py:5: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for key2, grp2 in grp1.groupby(['joinIteratorString']):

# %%
fig, ax = plt.subplots()
fig.set_figheight(15)
fig.set_figwidth(28)
for key1, grp1 in file.groupby(['ratio']):
    for key2, grp2 in grp1.groupby(['joinIteratorString']):
        ax = grp2.plot(ax=ax, kind='line', x='numberRight', y='head total', label= str(key1) + "; " + str(key2))
plt.legend(loc='best')
plt.show()
# Out:
# /tmp/ipykernel_19590/2307904283.py:4: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for key1, grp1 in file.groupby(['ratio']):
# /tmp/ipykernel_19590/2307904283.py:5: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for key2, grp2 in grp1.groupby(['joinIteratorString']):
# /tmp/ipykernel_19590/2307904283.py:5: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for key2, grp2 in grp1.groupby(['joinIteratorString']):
# /tmp/ipykernel_19590/2307904283.py:5: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for key2, grp2 in grp1.groupby(['joinIteratorString']):
# /tmp/ipykernel_19590/2307904283.py:5: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for key2, grp2 in grp1.groupby(['joinIteratorString']):
